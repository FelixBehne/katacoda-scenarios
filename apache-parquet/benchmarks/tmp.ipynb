# %%
from generate_data import generate_random_json
import pandas as pd
from io import StringIO
from fastparquet import write
import datatable as dt
import time

# %%
start = time.time()
df = dt.fread("~/Downloads/pp-complete.csv")
print(df.shape)
end = time.time()
print("time elapsed {}".format(end - start))

# %%
df = pd.read_json(StringIO(generate_random_json(1000000)), orient="records")

# %%
# %timeit 

write('outfile.parq', df)
# Out:
#                          Email Id Prefix              Name  Birth Date  \
# 0        jensenandrea@example.org    Dr.        Jon Nelson  13-09-1973
# 1       johnsonaustin@example.com   Miss       Megan Smith  02-11-1974
# 2       michaelvaldez@example.org    Mx.      Kelly Kelley  08-05-1970
# 3          smithshari@example.net    Dr.      Michael Wood  22-03-1977
# 4          bjefferson@example.net    Mx.   Kimberly Rivera  23-08-1983
# ..                            ...    ...               ...         ...
# 995         ophillips@example.net    Mr.    Sandra Schmidt  13-04-1971
# 996      kaylabradley@example.net    Ms.       Joshua Mann  15-01-1990
# 997    jonathancastro@example.com    Ms.  Christine Thomas  06-08-1996
# 998             kkent@example.org    Dr.   Elizabeth Gomez  18-10-1972
# 999  jennifercrawford@example.org    Dr.   Peggy Armstrong  19-10-1995
#
#               Phone Number                                            Address  \
# ...

# %%
# Out:
# '[{"Email Id": "morgan99@example.net", "Prefix": "Ind.", "Name": "Joseph Harris", "Birth Date": "08-07-1979", "Phone Number": "389-145-6098", "Address": "44093 Albert Walks\\nWest Triciaberg, KY 36312", "Zip Code": "19497", "City": "Robinburgh", "State": "Pennsylvania", "Country": "Italy", "Year": "1987", "Time": "19:44:42", "Link": "http://www.arias.net/", "Text": "want"}, {"Email Id": "morgan99@example.net", "Prefix": "Ind.", "Name": "Joseph Harris", "Birth Date": "08-07-1979", "Phone Number": "389-145-6098", "Address": "44093 Albert Walks\\nWest Triciaberg, KY 36312", "Zip Code": "19497", "City": "Robinburgh", "State": "Pennsylvania", "Country": "Italy", "Year": "1987", "Time": "19:44:42", "Link": "http://www.arias.net/", "Text": "want"}, {"Email Id": "morgan99@example.net", "Prefix": "Ind.", "Name": "Joseph Harris", "Birth Date": "08-07-1979", "Phone Number": "389-145-6098", "Address": "44093 Albert Walks\\nWest Triciaberg, KY 36312", "Zip Code": "19497", "City": "Robinburgh", "S
# ...
